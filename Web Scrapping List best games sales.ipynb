# %%
#Scrapping Data from Wikipedia + Pandas

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_best-selling_video_games'
#url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of best-selling video games - Wikipedia</title>
# ...

# %%
soup.find_all('table')[1]
# Out:
# <table class="wikitable sortable plainrowheaders">
# <caption><style data-mw-deduplicate="TemplateStyles:r1152813436">.mw-parser-output .sr-only{border:0;clip:rect(0,0,0,0);clip-path:polygon(0px 0px,0px 0px,0px 0px);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px;white-space:nowrap}</style><span class="sr-only">Overview of best-selling video games</span>
# </caption>
# <tbody><tr>
# <th scope="col">Title
# </th>
# <th scope="col">Sales
# </th>
# <th scope="col">Series
# </th>
# <th scope="col">Platform(s)
# </th>
# <th scope="col">Initial release date
# </th>
# <th scope="col">Developer(s)<sup class="reference" id="cite_ref-devpub_2-0"><a href="#cite_note-devpub-2"><span class="cite-bracket">[</span>b<span class="cite-bracket">]</span></a></sup>
# </th>
# <th scope="col">Publisher(s)<sup class="reference" id="cite_ref-devpub_2-1"><a href="#cite_note-devpub-2"><span class="cite-bracket">[</span>b<span class="cite-bracket">]</span></a></sup>
# </th>
# ...

# %%
soup.find('table', class_ = 'wikitable sortable plainrowheaders')
#<table class="wikitable sortable plainrowheaders jquery-tablesorter">
#<caption>
# Out:
# <table class="wikitable sortable plainrowheaders">
# <caption><style data-mw-deduplicate="TemplateStyles:r1152813436">.mw-parser-output .sr-only{border:0;clip:rect(0,0,0,0);clip-path:polygon(0px 0px,0px 0px,0px 0px);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px;white-space:nowrap}</style><span class="sr-only">Overview of best-selling video games</span>
# </caption>
# <tbody><tr>
# <th scope="col">Title
# </th>
# <th scope="col">Sales
# </th>
# <th scope="col">Series
# </th>
# <th scope="col">Platform(s)
# </th>
# <th scope="col">Initial release date
# </th>
# <th scope="col">Developer(s)<sup class="reference" id="cite_ref-devpub_2-0"><a href="#cite_note-devpub-2"><span class="cite-bracket">[</span>b<span class="cite-bracket">]</span></a></sup>
# </th>
# <th scope="col">Publisher(s)<sup class="reference" id="cite_ref-devpub_2-1"><a href="#cite_note-devpub-2"><span class="cite-bracket">[</span>b<span class="cite-bracket">]</span></a></sup>
# </th>
# ...

# %%
table = soup.find_all('table')[1]

# %%
print(table)
# Out:
# <table class="wikitable sortable plainrowheaders">
# <caption><style data-mw-deduplicate="TemplateStyles:r1152813436">.mw-parser-output .sr-only{border:0;clip:rect(0,0,0,0);clip-path:polygon(0px 0px,0px 0px,0px 0px);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px;white-space:nowrap}</style><span class="sr-only">Overview of best-selling video games</span>
# </caption>
# <tbody><tr>
# <th scope="col">Title
# </th>
# <th scope="col">Sales
# </th>
# <th scope="col">Series
# </th>
# <th scope="col">Platform(s)
# </th>
# <th scope="col">Initial release date
# </th>
# <th scope="col">Developer(s)<sup class="reference" id="cite_ref-devpub_2-0"><a href="#cite_note-devpub-2"><span class="cite-bracket">[</span>b<span class="cite-bracket">]</span></a></sup>
# </th>
# <th scope="col">Publisher(s)<sup class="reference" id="cite_ref-devpub_2-1"><a href="#cite_note-devpub-2"><span class="cite-bracket">[</span>b<span class="cite-bracket">]</span></a></sup>
# </th>
# ...

# %%
#name_of_titles = table.find_all('th')

header_row = table.find('tr')

# %%
#Mengambil nama kolom 

name_of_titles = [title.text.strip() for title in header_row.find_all('th')]
print(name_of_titles)

#name_of_titles = [title.text.strip() for title in name_of_titles]
#print(name_of_titles)
# Out:
# ['Title', 'Sales', 'Series', 'Platform(s)', 'Initial release date', 'Developer(s)[b]', 'Publisher(s)[b]', 'Ref.']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = name_of_titles)
df
# Out:
# Empty DataFrame
# Columns: [Title, Sales, Series, Platform(s), Initial release date, Developer(s)[b], Publisher(s)[b], Ref.]
# Index: []

# %%
#Ambil datanya 

import numpy as np

#skip header soalnya ada kotak nyangkut
for row in rows[1:]:
    row_data = []
    # Karena kolom title menggunakan th, maka kita lakukan cek th
    title_cell = row.find('th')
    if title_cell:
        row_data.append(title_cell.text.strip())  # Tambahkan data Title ke row_data
    # Ambil elemen <td> lainnya yang berisi value 
    cells = row.find_all('td')
    row_data.extend([cell.text.strip() for cell in cells])  # Tambahkan semua elemen <td> ke row_data

print(df)
# Out:
#                           Title        Sales            Series  \
# 0                     Minecraft  300,000,000         Minecraft
# 1            Grand Theft Auto V  205,000,000  Grand Theft Auto
# 2                    Wii Sports   82,900,000               Wii
# 3           PUBG: Battlegrounds   75,000,000     PUBG Universe
# 4         Mario Kart 8 / Deluxe   72,730,000        Mario Kart
# ..                          ...          ...               ...
# 129         Super Mario Bros. 3   24,430,000       Super Mario
# 130  Call of Duty: Black Ops II   24,200,000      Call of Duty
# 131          Kinect Adventures!   24,000,000              None
# 132                  Nintendogs   23,960,000        Nintendogs
# 133               Mario Kart DS   23,600,000        Mario Kart
#
#         Platform(s)  Initial release date  \
# 0    Multi-platform  November 18, 2011[c]
# 1    Multi-platform    September 17, 2013
# 2               Wii     November 19, 2006
# ...

# %%
df.to_csv(r'C:\Users\AYU SEKAR\OneDrive\Documents\KULIAH\Data Analyst 2027\Portofolio\Web Scrapping\Most sales games\Most Sales Games dataset.csv', index = False)
